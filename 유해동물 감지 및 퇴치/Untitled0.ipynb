# %%
from glob import glob

img_list = glob('/content/drive/MyDrive/project_BigData/21_08_09_datasets/train/images/*.jpg')

print(len(img_list))
# Out:
# 2182

# %%
from sklearn.model_selection import train_test_split
train_img_list, val_img_list = train_test_split(img_list, test_size=0.2, random_state = 2000)
print(len(train_img_list), len(val_img_list))
# Out:
# 1745 437

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
with open('/content/drive/MyDrive/project_BigData/21_08_09_datasets/train.txt', 'w') as f:
  f.write('\n'.join(train_img_list)+'\n')
with open('/content/drive/MyDrive/project_BigData/21_08_09_datasets/val.txt', 'w') as f:
  f.write('\n'.join(val_img_list)+'\n')

# %%
import yaml

# %%
with open('/content/drive/MyDrive/project_BigData/21_08_09_datasets/data.yaml','r') as f:
  data = yaml.load(f)
data
# Out:
# {'names': ['boar', 'gorani', 'human'],
#  'nc': 3,
#  'train': '/content/drive/MyDrive/project_BigData/21_08_09_datasets/train.txt',
#  'val': '/content/drive/MyDrive/project_BigData/21_08_09_datasets/val.txt'}

# %%
data['train'] = '/content/drive/MyDrive/project_BigData/21_08_09_datasets/train.txt'
data['val'] = '/content/drive/MyDrive/project_BigData/21_08_09_datasets/val.txt'

with open('/content/drive/MyDrive/project_BigData/21_08_09_datasets/data.yaml','w') as f:
  yaml.dump(data, f)
print(data)
# Out:
# {'names': ['boar', 'gorani', 'human'], 'nc': 3, 'train': '/content/drive/MyDrive/project_BigData/21_08_09_datasets/train.txt', 'val': '/content/drive/MyDrive/project_BigData/21_08_09_datasets/val.txt'}

# %%
# %cd /content/drive/MyDrive/project_BigData/
# Out:
# /content/drive/MyDrive/project_BigData

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/project_BigData/.git/

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# %cd /content/drive/MyDrive/project_BigData/yolov5
# Out:
# /content/drive/MyDrive/project_BigData/yolov5

# %%
# !python train.py --img 380 --batch 32 --epochs 50 --data /content/drive/MyDrive/project_BigData/21_08_09_datasets/data.yaml --cfg /content/drive/MyDrive/project_BigData/yolov5/models/yolov5m.yaml --weights yolov5m.pt --name 50_medium
# Out:
# train: weights=yolov5m.pt, cfg=/content/drive/MyDrive/project_BigData/yolov5/models/yolov5m.yaml, data=/content/drive/MyDrive/project_BigData/21_08_09_datasets/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=50, batch_size=32, imgsz=380, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, entity=None, name=50_medium, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0
# github: ⚠️ WARNING: code is out of date by 18 commits. Use 'git pull' to update or 'git clone https://github.com/ultralytics/yolov5' to download latest.
# YOLOv5 🚀 2021-8-6 torch 1.9.0+cu102 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# !pwd
# Out:
# /content/drive/My Drive/project_BigData/yolov5
